# %%
import pickle
import numpy as np
import xgboost as xgb
from sklearn.cross_validation import KFold
import pandas as pd

#rng = np.random.RandomState(31337)

train = pickle.load(open("/codilime/data/train_processed.p", "rb"))
test = pickle.load(open("/codilime/data/test_processed.p", "rb"))
train["y"]
# Out:
# [16.0,
#  40.0,
#  32.0,
#  13.0,
#  1.0,
#  1.0,
#  2.0,
#  3.0,
#  8.0,
#  14.0,
#  36.0,
#  56.0,
#  84.0,
#  94.0,
#  106.0,
#  110.0,
#  93.0,
#  67.0,
#  35.0,
#  37.0,
#  36.0,
#  34.0,
#  28.0,
#  39.0,
#  17.0,
#  17.0,
#  9.0,
#  6.0,
#  3.0,
#  2.0,
#  1.0,
#  8.0,
#  20.0,
#  53.0,
#  70.0,
#  93.0,
#  75.0,
#  59.0,
#  74.0,
#  76.0,
#  65.0,
#  53.0,
#  30.0,
#  22.0,
#  31.0,
#  9.0,
#  8.0,
#  5.0,
#  2.0,
#  1.0,
#  3.0,
#  30.0,
#  64.0,
#  154.0,
#  88.0,
#  44.0,
#  51.0,
#  61.0,
#  61.0,
#  77.0,
#  72.0,
#  76.0,
#  157.0,
#  157.0,
#  110.0,
#  52.0,
#  52.0,
#  20.0,
#  12.0,
#  5.0,
#  2.0,
#  1.0,
#  2.0,
#  4.0,
#  36.0,
#  94.0,
#  179.0,
#  100.0,
#  42.0,
#  57.0,
#  78.0,
#  97.0,
#  63.0,
#  65.0,
#  83.0,
#  212.0,
#  182.0,
#  112.0,
#  54.0,
#  48.0,
#  35.0,
#  11.0,
#  6.0,
#  6.0,
#  2.0,
#  2.0,
#  3.0,
#  33.0,
#  88.0,
#  195.0,
#  115.0,
#  57.0,
#  46.0,
#  79.0,
#  71.0,
#  62.0,
#  62.0,
#  89.0,
#  190.0,
#  169.0,
#  132.0,
#  89.0,
# ...

# %%
X = train["X"]
y = train["y"]

# y = np.array(pickle.load(open("/codilime/data/test_processed.p", "rb")))
#err = []
#kf = KFold(y.shape[0], n_folds=2, shuffle=True, random_state=rng)
#for train_index, test_index in kf:
xgb_model = xgb.XGBRegressor().fit(X,y)
predictions = xgb_model.predict(test["X"])
print(predictions)
#err
# Out:
# [  3.29882145  18.74206924  13.223032   ...,  85.08275604  53.45053101
#   29.73861885]

# %%
df_test = pd.read_csv('/codilime/data/test.csv')
df_test
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-20 00:00:00       1        0           1        1  10.66
# 1     2011-01-20 01:00:00       1        0           1        1  10.66
# 2     2011-01-20 02:00:00       1        0           1        1  10.66
# 3     2011-01-20 03:00:00       1        0           1        1  10.66
# 4     2011-01-20 04:00:00       1        0           1        1  10.66
# 5     2011-01-20 05:00:00       1        0           1        1   9.84
# 6     2011-01-20 06:00:00       1        0           1        1   9.02
# 7     2011-01-20 07:00:00       1        0           1        1   9.02
# 8     2011-01-20 08:00:00       1        0           1        1   9.02
# 9     2011-01-20 09:00:00       1        0           1        2   9.84
# 10    2011-01-20 10:00:00       1        0           1        1  10.66
# 11    2011-01-20 11:00:00       1        0           1        2  11.48
# ...

# %%
submission_df = df_test[["datetime"]].copy()

# %%
submission_df["count"] = np.array(predictions)

# %%
submission_df.to_csv('/codilime/data/submission.csv', index=False)

# %%
submission_df.columns
# Out:
# Index(['datetime', 'count'], dtype='object')

# %%
submission_df
# Out:
#                  datetime       count
# 0     2011-01-20 00:00:00    3.298821
# 1     2011-01-20 01:00:00   18.742069
# 2     2011-01-20 02:00:00   13.223032
# 3     2011-01-20 03:00:00    7.413963
# 4     2011-01-20 04:00:00    7.413963
# 5     2011-01-20 05:00:00    9.938645
# 6     2011-01-20 06:00:00   66.829544
# 7     2011-01-20 07:00:00  185.508774
# 8     2011-01-20 08:00:00  317.517059
# 9     2011-01-20 09:00:00  121.385269
# 10    2011-01-20 10:00:00   76.556702
# 11    2011-01-20 11:00:00   76.485703
# 12    2011-01-20 12:00:00  112.172195
# 13    2011-01-20 13:00:00   90.221481
# 14    2011-01-20 14:00:00  101.454201
# 15    2011-01-20 15:00:00  105.193306
# 16    2011-01-20 16:00:00  145.802444
# 17    2011-01-20 17:00:00  313.188263
# 18    2011-01-20 18:00:00  297.588409
# 19    2011-01-20 19:00:00  187.833755
# 20    2011-01-20 20:00:00   96.502594
# 21    2011-01-20 21:00:00   70.383591
# 22    2011-01-20 22:00:00   36.422745
# 23    2011-01-20 23:00:00    8.194880
# ...
